# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
# Read an image
img = cv.imread('rose.jpeg')

new_img = cv.cvtColor(img,cv.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.show()
plt.imshow(new_img)
plt.show()
